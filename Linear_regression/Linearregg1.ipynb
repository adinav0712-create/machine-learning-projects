# %%
#LINEAR REGRESSION

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sb
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('instagram_likes_100_records.csv')

# %%
df

# %%
df.head()

# %%
x=df.drop('likes',axis='columns')
x

# %%
y=df.likes
y

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train

# %%
x_test

# %%
y_train

# %%
y_test

# %%
reg = linear_model.LinearRegression()
reg.fit(x_train,y_train)

# %%
reg.predict([[12000,23,60,5]])

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, lin_pred)
plt.xlabel("Actual Likes")
plt.ylabel("Predicted Likes")
plt.title("Actual vs Predicted Likes")
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()])
plt.savefig("prediction_check.png")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
lin_reg=LinearRegression()
lin_reg.fit(x_train,y_train)

lin_pred=lin_reg.predict(x_test)
lin_acc=r2_score(y_test,lin_pred)*100

print(f"Linear Regression Accuraccy: {lin_acc:.2f}%")

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_s = scaler.fit_transform(x_train)
X_test_s = scaler.transform(x_test)

model = LinearRegression()
model.fit(X_train_s, y_train)

pred = model.predict(X_test_s)

# %%
from sklearn.metrics import r2_score, mean_absolute_error

r2 = r2_score(y_test, pred) * 100
mae = mean_absolute_error(y_test, pred)

print(f"R2 Score: {r2:.2f}%")
print(f"MAE: {mae:.2f}")

# %%
import pandas as pd

result = pd.DataFrame({
    "Actual Likes": y_test.values,
    "Predicted Likes": pred.astype(int)
})

print(result.head(10))
